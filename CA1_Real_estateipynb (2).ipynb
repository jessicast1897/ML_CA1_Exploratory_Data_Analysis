# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("https://raw.githubusercontent.com/ArinB/MSBA-CA-Data/main/CA01/house-price-train.csv")

# %%
#Part 1: Data Understanding – Output of this part will be various visualization of the variable analysis
#and finally the Data Quality Report that will identify the data problems that exist in this datase
print(df.head())
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df.describe(include='object')
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1  ... GarageType GarageFinish  \
# count       1460         1460       1460  ...       1379         1379
# unique         3           25          9  ...          6            3
# top          Gtl        NAmes       Norm  ...     Attchd          Unf
# freq        1382          225       1260  ...        870          605
#
#        GarageQual GarageCond PavedDrive PoolQC  Fence MiscFeature SaleType  \
# count        1379       1379       1460      7    281          54     1460
# unique          5          5          3      3      4           4        9
# ...

# %%
#identifying variable types
target='SalePrice'
numeric_cols = df.select_dtypes(include=['int64','float64']).columns
categorical_cols = df.select_dtypes(include=['object']).columns

# %%
#single variable (univariate) analysis
#numeric features
plt.hist(df['SalePrice'])
plt.xlabel('SalePrice')
plt.ylabel('Count')
plt.title('Distribution of SalePrice')
plt.show()

# %%
plt.boxplot(x=df['LotArea'])
plt.title('Boxplot of Lot Area')
plt.show()

# %%
#categorical features
df['Neighborhood'].value_counts().plot(kind='bar')
plt.title('Number of properties in Neighborhoods')
plt.ylabel('Count')
plt.show()

# %%
df['BldgType'].value_counts().plot(kind='bar')
plt.title('Count of Building Type')
plt.ylabel('Count')
plt.show()

# %%
#Bivariate Analysis (feature vs target)
#numeric vs target
plt.scatter(df['LotArea'],df['SalePrice'],alpha=0.5)
plt.xlabel('LotArea')
plt.ylabel('SalePrice')
plt.title('Lot Area vs Sale Price')
plt.show()

# %%
#categorical vs target
sns.boxplot(x='BldgType', y='SalePrice',data=df)
plt.title('Building Type vs Sale Price')
plt.show()

# %%
#multivariate overview
#correlation heatmap for numeric values
sns.heatmap(df[numeric_cols].corr(),cmap='coolwarm',center=0)
plt.title('Correlation Heatmap')
plt.show()

# %%
#drop low correlated columns
#bsmtfinsf2, enclosedporch, screenporch, miscval, yrsold

# %%
#pairplot to visualize the relationshops between mutliple numeric columns
sns.pairplot(df,vars=['OverallQual','YearBuilt','2ndFlrSF'])
plt.show()

# %%
#violin plot to visualize the distribution of a numeric column
sns.violinplot(x='YrSold',y='YearBuilt',data=df)
plt.ylabel('Year Built')
plt.show()

# %%
#create a regression plot to visualize the relationship betwwen two numeric columns
sns.regplot(x='Fireplaces',y='GarageCars',data=df)
# Out:
# <Axes: xlabel='Fireplaces', ylabel='GarageCars'>

# %%
#data quality Report
data_quality = pd.DataFrame({
    'Data Type': df.dtypes,
    'Missing Values': df.isnull().sum(),
    'Missing %': (df.isnull().sum() / len(df)) * 100,
    'Unique Values': df.nunique()
})
data_quality.sort_values('Missing %', ascending=False)
# Out:
#               Data Type  Missing Values  Missing %  Unique Values
# PoolQC           object            1453  99.520548              3
# MiscFeature      object            1406  96.301370              4
# Alley            object            1369  93.767123              2
# Fence            object            1179  80.753425              4
# MasVnrType       object             872  59.726027              3
# ...                 ...             ...        ...            ...
# MoSold            int64               0   0.000000             12
# YrSold            int64               0   0.000000              5
# SaleType         object               0   0.000000              9
# SaleCondition    object               0   0.000000              6
# SalePrice         int64               0   0.000000            663
#
# [81 rows x 4 columns]

# %%
#quality checks

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
data_quality[data_quality['Unique Values'] <= 1]
# Out:
# Empty DataFrame
# Columns: [Data Type, Missing Values, Missing %, Unique Values]
# Index: []

# %%
data_quality[data_quality['Unique Values'] > 0.95 * len(df)]
# Out:
#    Data Type  Missing Values  Missing %  Unique Values
# Id     int64               0        0.0           1460

# %%
#summary
#no duplicated rows were found.
#1FAM building types have the largest range in prices
#there are outliers for lot size
#Sale price is right skewed


#justifciation of dropped columns
#BSMTFINSF2
#Enclosedporch
#ScreenPorch
#MiscVal
#YrSold
#all have little to zero correlation with price therefore we can drop these columns in the following steps.

# %%
#data preprocessing

# %%
#copy of data
df_clean=df.copy()

# %%
#check for duplicates
dup_count = df_clean.duplicated().sum()
print("Duplicate rows:", dup_count)
if dup_count > 0:
    df_clean = df_clean.drop_duplicates()
# Out:
# Duplicate rows: 0

# %%
#serparate feature types
numeric_cols = df_clean.select_dtypes(include=["int64", "float64"]).columns
categorical_cols = df_clean.select_dtypes(include=["object"]).columns

# %%
#missing value report
missing = df_clean.isna().sum()
missing_pct = (missing / len(df_clean)) * 100
missing_report = (pd.DataFrame({"missing": missing, "missing_pct": missing_pct}).sort_values("missing_pct", ascending=False))
missing_report
# Out:
#                missing  missing_pct
# PoolQC            1453    99.520548
# MiscFeature       1406    96.301370
# Alley             1369    93.767123
# Fence             1179    80.753425
# MasVnrType         872    59.726027
# ...                ...          ...
# MoSold               0     0.000000
# YrSold               0     0.000000
# SaleType             0     0.000000
# SaleCondition        0     0.000000
# SalePrice            0     0.000000
#
# [81 rows x 2 columns]

# %%
#drop columns with lots of missing values
miss_thresh = 60
cols_drop = missing_report[missing_report["missing_pct"]>miss_thresh].index.tolist()
#dont drop sale price
cols_to_drop = [c for c in cols_drop if c != target]
cols_to_drop
# Out:
# ['PoolQC', 'MiscFeature', 'Alley', 'Fence']

# %%
#must drop the above

# %%
df_clean=df_clean.drop(columns=cols_to_drop)

# %%
#recalc columns lists
numeric_cols = df_clean.select_dtypes(include=["int64", "float64"]).columns
categorical_cols = df_clean.select_dtypes(include=["object"]).columns

# %%
#fix missing values numerical
num_fill_cols = [c for c in numeric_cols if c != target]
for c in num_fill_cols:
    if df_clean[c].isna().sum() > 0:
        df_clean[c] = df_clean[c].fillna(df_clean[c].median())

# %%
#fix categorical
for c in categorical_cols:
    if df_clean[c].isna().sum() > 0:
        df_clean[c] = df_clean[c].fillna("Unknown")

# %%
print("Missing values after imputation:", df_clean.isna().sum().sum())
# Out:
# Missing values after imputation: 0

# %%
#checking for other ID columns
id_like = []
for c in df_clean.columns:
    if c != target:
        if df_clean[c].nunique() >= 0.99 * len(df_clean):
            id_like.append(c)

print("ID-like columns:", id_like)
# Out:
# ID-like columns: ['Id']

# %%
#one hot encoding
y = df_clean[target]
X = df_clean.drop(columns=[target])

X_encoded = pd.get_dummies(X, columns=X.select_dtypes(include=["object"]).columns, drop_first=True)

df_ready = pd.concat([X_encoded, y], axis=1)

# %%
df_ready.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLw  SaleType_New  \
# 0          2003       196.0         706  ...           False         False
# 1          1976         0.0         978  ...           False         False
# 2          2002       162.0         486  ...           False         False
# 3          1970         0.0         216  ...           False         False
# 4          2000       350.0         655  ...           False         False
#
# ...

# %%
#ID column is now an index

# %%
#3 collinearity and feature selection (no class imbalance)

# %%
df_part3=df_ready.copy()

# %%
#correlation matrix
#find low correlation and delete from model
#find high collinearity and delete from model
numeric_cols = df_part3.select_dtypes(include=["int64", "float64"]).columns

corr = df_part3[numeric_cols].corr()

plt.figure(figsize=(14, 10))
sns.heatmap(corr, center=0)
plt.title("Correlation Heatmap (All Numeric Features)")
plt.show()

# %%
df_part3.head()
df_part3=df_part3.drop(columns=['Id','MSSubClass','OverallCond','BsmtFinSF2','LowQualFinSF','BsmtHalfBath','KitchenAbvGr','EnclosedPorch','3SsnPorch','ScreenPorch','PoolArea','MiscVal','MoSold','YrSold','OpenPorchSF','WoodDeckSF'])

# %%
corr2=df_part3.corr(numeric_only=True)
sns.heatmap(corr)
plt.show()

# %%
upper = corr_features.where(np.triu(np.ones(corr_features.shape), k=1).astype(bool))

high_corr_pairs = (
    upper.stack()
    .reset_index()
    .rename(columns={"level_0": "Feature_A", "level_1": "Feature_B", 0: "AbsCorr"})
    .sort_values("AbsCorr", ascending=False)
)

high_corr_pairs = high_corr_pairs[high_corr_pairs["AbsCorr"] >= CORR_THRESHOLD]

print(f"Highly correlated feature pairs (|corr| >= {CORR_THRESHOLD}):")
display(high_corr_pairs.head(30))
# Out:
# Highly correlated feature pairs (|corr| >= 0.9):
# Empty DataFrame
# Columns: [Feature_A, Feature_B, AbsCorr]
# Index: []

# %%
#there are no highly correlated feature pairs. We can also see this on the heatmap

# %% [markdown]
# Conclusion
# Some features had a large amount of missing values. Housing prices vary and have outliers but start at about 100000 dollars. There are more 1Fam homes than anything else. YrSold graph shows that there was a concentration aroudn 2006-2010. There are some features that only occur in some houses such as pool area, or fireplace.

# %% [markdown]
# 'Id','MSSubClass','OverallCond','BsmtFinSF2','LowQualFinSF','BsmtHalfBath','KitchenAbvGr','EnclosedPorch','3SsnPorch','ScreenPorch','PoolArea','MiscVal','MoSold','YrSold','OpenPorchSF','WoodDeckSF' were dropped due to low correlation with the target and ['PoolQC', 'MiscFeature', 'Alley', 'Fence'] were dropped due to missing data
